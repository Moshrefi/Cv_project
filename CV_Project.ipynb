# %%
# %cd drive/MyDrive/Projects/CV_Project/
# Out:
# /content/drive/MyDrive/Projects/CV_Project

# %%
# !git clone https://github.com/wdttt/LocoTrans.git
# Out:
# fatal: destination path 'LocoTrans' already exists and is not an empty directory.

# %%
# %cd LocoTrans/
# Out:
# /content/drive/MyDrive/Projects/CV_Project/LocoTrans

# %%
# !pip install -q torch torchvision torchaudio
# !pip install -q 'git+https://github.com/facebookresearch/pytorch3d.git'
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python main_cls_l.py --exp_name=modelnet40_cls --rot=z --eval=True --model_path pretrained_l/model_1_z.t7
# Out:
# Namespace(exp_name='modelnet40_cls', model='iecnn', dataset='modelnet40', batch_size=32, test_batch_size=16, epochs=250, use_sgd=True, lr=0.001, momentum=0.9, no_cuda=False, seed=2, eval=True, num_points=1024, dropout=0.5, emb_dims=1024, k=20, model_path='pretrained_l/model_1_z.t7', checkpoint='model_1', rot='z', pooling='mean', loss_orth=0.1, loss_consist=0.1, shift=0.15, add_layer=False)
# Using GPU : 0 from 1 devices
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Projects/CV_Project/LocoTrans/main_cls_l.py", line 393, in <module>
#     test(args, io)
#   File "/content/drive/MyDrive/Projects/CV_Project/LocoTrans/main_cls_l.py", line 257, in test
#     test_loader = DataLoader(ModelNet40(partition='test', num_points=args.num_points),
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: ModelNet40.__init__() missing 1 required positional argument: 'root_dir'

# %%
# !python main_cls_l.py --exp_name=modelnet40_cls --rot=z --eval=True --model_path pretrained_l/model_1_z.t7 --test_batch_size 4
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
#  82% 503/617 [36:31<53:27, 28.13s/it]Warning: Cannot parse number of vertices in data/ModelNet40/table/test/table_0395.off: 11.220482
# ...
# ...
# ...
#  85% 523/617 [36:51<00:57,  1.65it/s]Warning: Cannot parse number of vertices in data/ModelNet40/table/test/table_0451.off: -0.984200
# ...
#  85% 524/617 [36:51<00:51,  1.81it/s]Warning: Cannot parse number of vertices in data/ModelNet40/table/test/table_0456.off: -22.834650
# ...
#  85% 525/617 [36:51<00:44,  2.05it/s]Warning: Cannot parse number of vertices in data/ModelNet40/table/test/table_0444.off: 9.375000
# ...
#  85% 526/617 [36:52<00:40,  2.24it/s]Warning: Cannot parse number of vertices in data/ModelNet40/table/test/table_0467.off: 10.500000
# ...
# 100% 617/617 [42:22<00:00,  4.12s/it]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:2524: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# ...

# %%
# !gdown --id 1N3v4JWv5wbGpCcgf8q0uUOcKqWzSLtZV
# !unzip modelnet40_normal_resampled.zip -d data/
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1N3v4JWv5wbGpCcgf8q0uUOcKqWzSLtZV
#
# but Gdown can't. Please check connections and permissions.
# unzip:  cannot find or open modelnet40_normal_resampled.zip, modelnet40_normal_resampled.zip.zip or modelnet40_normal_resampled.zip.ZIP.

# %%
# !python main_cls.py --exp_name=modelnet40_cls --rot=z --eval=True --model_path pretrained/model_1_z.t7
# Out:
# Namespace(exp_name='modelnet40_cls', model='iecnn', dataset='modelnet40', batch_size=4, test_batch_size=16, epochs=250, use_sgd=True, lr=0.001, momentum=0.9, no_cuda=False, seed=2, eval=True, num_points=1024, dropout=0.5, emb_dims=1024, k=20, model_path='pretrained/model_1_z.t7', checkpoint='model_1', rot='z', pooling='mean', loss_orth=0.1, loss_consist=0.1, shift=0.2, add_layer=True)
# Using GPU : 0 from 1 devices
# IECNN_cls(
#   (conv1_vn): VNLinearLeakyReLU(
#     (map_to_feat): Linear(in_features=2, out_features=21, bias=False)
#     (batchnorm): VNBatchNorm(
#       (bn): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (map_to_dir): Linear(in_features=2, out_features=21, bias=False)
#   )
#   (conv2_vn): VNLinearLeakyReLU(
#     (map_to_feat): Linear(in_features=42, out_features=21, bias=False)
#     (batchnorm): VNBatchNorm(
#       (bn): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
# ...
